# %% [markdown]
# # Time Plots

# %%
require(astsa)
# Out:
# Loading required package: astsa

# %% [markdown]
# The Dataset can be explored through this index.<br><br>
# [Dataset-01: Jhonson & Jhonson](#1.-Johnson-and-Johnson-Quarterly-Earnings-Per-Share)<br>
# [Dataset-02: Monthly Pneumonia and Influenza Deaths in the U.S.](#2.-Monthly-Pneumonia-and-Influenza-Deaths-in-the-U.S.)<br>
# [Dataset-03: Global Mean Land-Ocean Temperature Deviations](#3.-Global-Mean-Land-Ocean-Temperature-Deviations)<br>
# [Dataset-04: Global Mean Land Temperature Deviations](#4.-Global-Mean-Land-Temperature-Deviations)<br>
# [Dataset 05: Variable Star](#5.-Variable-Star)<br>

# %% [markdown]
# ## 1. Johnson and Johnson Quarterly Earnings Per Share

# %%
help(jj)

# %%
class(jj)
# Out:
# [1] "ts"

# %%
print(jj)
# Out:
#           Qtr1      Qtr2      Qtr3      Qtr4
# 1960  0.710000  0.630000  0.850000  0.440000
# 1961  0.610000  0.690000  0.920000  0.550000
# 1962  0.720000  0.770000  0.920000  0.600000
# 1963  0.830000  0.800000  1.000000  0.770000
# 1964  0.920000  1.000000  1.240000  1.000000
# 1965  1.160000  1.300000  1.450000  1.250000
# 1966  1.260000  1.380000  1.860000  1.560000
# 1967  1.530000  1.590000  1.830000  1.860000
# 1968  1.530000  2.070000  2.340000  2.250000
# 1969  2.160000  2.430000  2.700000  2.250000
# 1970  2.790000  3.420000  3.690000  3.600000
# 1971  3.600000  4.320000  4.320000  4.050000
# 1972  4.860000  5.040000  5.040000  4.410000
# 1973  5.580000  5.850000  6.570000  5.310000
# 1974  6.030000  6.390000  6.930000  5.850000
# 1975  6.930000  7.740000  7.830000  6.120000
# 1976  7.740000  8.910000  8.280000  6.840000
# 1977  9.540000 10.260000  9.540000  8.729999
# 1978 11.880000 12.060000 12.150000  8.910000
# 1979 14.040000 12.960000 14.850000  9.990000
# ...

# %%
options(repr.plot.width=9, repr.plot.height=5)
plot(jj, type = "o", 
     col="blue", 
     main="Johnson and Johnson quarterly earnings per share",
     xlab="Years", 
     ylab="Earnings")
# Out:
# Plot with title "Johnson and Johnson quarterly earnings per share"

# %%
jj.linear.model <- lm(jj ~ time(jj))
jj.poly2.model <- lm(jj ~ poly(time(jj), 2, raw=TRUE))
jj.sinos.model <- lm(jj ~ poly(time(jj), 2, raw=TRUE)*sin(pi + 2*pi*(time(jj)-1959)))

plot(jj, type = "o", 
     col="green", 
     main="Johnson and Johnson quarterly earnings per share",
     xlab="Years", 
     ylab="Earnings", lwd = 1.2)

lines(x = as.vector(time(jj)), y = predict(jj.linear.model), col = 'red', lwd = 1.7)
lines(x = as.vector(time(jj)), y = predict(jj.poly2.model), col = 'blue', lwd = 1.7)
lines(x = as.vector(time(jj)), y = predict(jj.sinos.model), col = 'brown', lwd = 1.7)

legend(x = "left", 
       y = "top", 
       legend=c("Original Time Series", "Linear Model", "Quadratic Model", "Quadratic Sinousoidal Model"), 
       col=c("green", "red", "blue", "brown"), 
       lwd=2, 
       text.font=0.2)
# Out:
# Plot with title "Johnson and Johnson quarterly earnings per share"

# %%
summary(jj.linear.model)
# Out:
# Call:
# lm(formula = jj ~ time(jj))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.1853 -1.1968 -0.5239  0.8742  5.1229
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.280e+03  5.926e+01  -21.61   <2e-16 ***
# time(jj)     6.522e-01  3.007e-02   21.69   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.671 on 82 degrees of freedom
# Multiple R-squared:  0.8515,	Adjusted R-squared:  0.8497
# F-statistic: 470.3 on 1 and 82 DF,  p-value: < 2.2e-16

# %%
summary(jj.poly2.model)
# Out:
# Call:
# lm(formula = jj ~ poly(time(jj), 2, raw = TRUE))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -3.07418 -0.21177  0.08893  0.31063  2.77309
#
# Coefficients:
#                                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)                     1.619e+05  1.187e+04   13.64   <2e-16 ***
# poly(time(jj), 2, raw = TRUE)1 -1.650e+02  1.205e+01  -13.70   <2e-16 ***
# poly(time(jj), 2, raw = TRUE)2  4.204e-02  3.057e-03   13.75   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9206 on 81 degrees of freedom
# Multiple R-squared:  0.9555,	Adjusted R-squared:  0.9544
# F-statistic: 869.2 on 2 and 81 DF,  p-value: < 2.2e-16

# %%
summary(jj.sinos.model)
# Out:
# Call:
# lm(formula = jj ~ poly(time(jj), 2, raw = TRUE) * sin(pi + 2 *
#     pi * (time(jj) - 1959)))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.31505 -0.26595  0.01455  0.20174  2.67007
#
# Coefficients:
#                                                                       Estimate
# (Intercept)                                                          1.653e+05
# poly(time(jj), 2, raw = TRUE)1                                      -1.685e+02
# poly(time(jj), 2, raw = TRUE)2                                       4.291e-02
# sin(pi + 2 * pi * (time(jj) - 1959))                                -3.737e+04
# poly(time(jj), 2, raw = TRUE)1:sin(pi + 2 * pi * (time(jj) - 1959))  3.803e+01
# poly(time(jj), 2, raw = TRUE)2:sin(pi + 2 * pi * (time(jj) - 1959)) -9.675e-03
#                                                                     Std. Error
# (Intercept)                                                          8.846e+03
# ...

# %% [markdown]
# We can clearly see that the the Adjusted R square is the highest in case of Quadratic Sinousoidal signal.

# %%
plot(jj.linear.model)
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""

# %%
plot(jj.poly2.model)
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""

# %%
plot(jj.sinos.model)
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""

# %% [markdown]
# [Go To Index Section](#Time-Plots)

# %% [markdown]
# ## 2. Monthly Pneumonia and Influenza Deaths in the U.S.

# %%
help(flu)

# %%
class(flu)
# Out:
# [1] "ts"

# %%
print(flu)
# Out:
#            Jan       Feb       Mar       Apr       May       Jun       Jul
# 1968 0.8113721 0.4458291 0.3415985 0.2774243 0.2484958 0.2525427 0.2466902
# 1969 0.8192756 0.4376872 0.3834813 0.2919304 0.2556420 0.2369918 0.2495123
# 1970 0.4932865 0.5692177 0.3593959 0.2741868 0.2424912 0.2241473 0.2280840
# 1971 0.3743171 0.3746391 0.3398281 0.2909505 0.2403667 0.2269297 0.2134564
# 1972 0.6381312 0.5195216 0.2968231 0.2514277 0.2144966 0.1964111 0.2343862
# 1973 0.5968794 0.5156948 0.3085772 0.2569596 0.2194814 0.2158074 0.2240929
# 1974 0.3096678 0.3330646 0.3497020 0.3066515 0.2238370 0.2030033 0.2231299
# 1975 0.4937200 0.4728154 0.3094317 0.2343683 0.2007220 0.1906996 0.1877136
# 1976 0.2902977 0.5702096 0.6384278 0.3135166 0.2047724 0.1885323 0.1798065
# 1977 0.2817310 0.3030367 0.2915253 0.2453148 0.2051037 0.1845583 0.2046436
# 1978 0.5712671 0.4351815 0.2825850 0.2381904 0.2196089 0.1904820 0.1926964
#            Aug       Sep       Oct       Nov       Dec
# ...

# %%
options(repr.plot.width=9, repr.plot.height=5)
plot(flu, type = "o", 
     col="blue", 
     main="Monthly Pneumonia and Influenza Deaths in the U.S.",
     xlab="Years", 
     ylab="Deaths per 10000 People")
# Out:
# Plot with title "Monthly Pneumonia and Influenza Deaths in the U.S."

# %% [markdown]
# This plots suggests there is some sesonality in the data.

# %%
flu.linear.model <- lm(flu ~ time(flu))
flu.poly2.model <- lm(flu ~ poly(time(flu), 2, raw=TRUE))
flu.sinos.model <- lm(flu ~ time(flu) * abs(sin(2*pi*(time(flu))/2)))

plot(flu, type = "o", 
     col="green", 
     main="Monthly Pneumonia and Influenza Deaths in the U.S.",
     xlab="Years", 
     ylab="Deaths per 10000 People")

lines(x = as.vector(time(flu)), y = predict(flu.linear.model), col = 'red', lwd = 1.7)
lines(x = as.vector(time(flu)), y = predict(flu.poly2.model), col = 'blue', lwd = 1.7)
lines(x = as.vector(time(flu)), y = predict(flu.sinos.model), col = 'brown', lwd = 1.7)

legend(x = "topright", 
       legend=c("Original Time Series", "Linear Model", "Quadratic Model", "Linear Absolute Sinousoidal Model"), 
       col=c("green", "red", "blue", "brown"), 
       lwd=2, 
       text.font=0.2)
# Out:
# Plot with title "Monthly Pneumonia and Influenza Deaths in the U.S."

# %%
summary(flu.linear.model)
# Out:
# Call:
# lm(formula = flu ~ time(flu))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.11652 -0.07402 -0.04307  0.02754  0.47845
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 21.96732    6.55146   3.353  0.00105 **
# time(flu)   -0.01098    0.00332  -3.308  0.00121 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.1211 on 130 degrees of freedom
# Multiple R-squared:  0.07766,	Adjusted R-squared:  0.07057
# F-statistic: 10.95 on 1 and 130 DF,  p-value: 0.001214

# %%
summary(flu.poly2.model)
# Out:
# Call:
# lm(formula = flu ~ poly(time(flu), 2, raw = TRUE))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.13348 -0.07000 -0.03968  0.03057  0.46555
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      5.151e+03  4.548e+03   1.133    0.259
# poly(time(flu), 2, raw = TRUE)1 -5.209e+00  4.609e+00  -1.130    0.261
# poly(time(flu), 2, raw = TRUE)2  1.317e-03  1.168e-03   1.128    0.262
#
# Residual standard error: 0.121 on 129 degrees of freedom
# Multiple R-squared:  0.08667,	Adjusted R-squared:  0.07251
# F-statistic:  6.12 on 2 and 129 DF,  p-value: 0.002888

# %%
summary(flu.sinos.model)
# Out:
# Call:
# lm(formula = flu ~ time(flu) * abs(sin(2 * pi * (time(flu))/2)))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.16170 -0.03497 -0.00604  0.01997  0.34604
#
# Coefficients:
#                                              Estimate Std. Error t value
# (Intercept)                                 52.201746   9.162546   5.697
# time(flu)                                   -0.026213   0.004643  -5.645
# abs(sin(2 * pi * (time(flu))/2))           -50.262940  12.985874  -3.871
# time(flu):abs(sin(2 * pi * (time(flu))/2))   0.025325   0.006581   3.848
#                                            Pr(>|t|)
# (Intercept)                                7.95e-08 ***
# time(flu)                                  1.01e-07 ***
# abs(sin(2 * pi * (time(flu))/2))           0.000172 ***
# time(flu):abs(sin(2 * pi * (time(flu))/2)) 0.000187 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.07572 on 128 degrees of freedom
# ...

# %%
plot(flu.linear.model)
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""

# %%
plot(flu.poly2.model)
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""

# %%
plot(flu.sinos.model)
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""

# %% [markdown]
# [Go To Index Section](#Time-Plots)

# %% [markdown]
# ## 3. Global Mean Land-Ocean Temperature Deviations

# %%
help(globtemp)

# %%
class(globtemp)
# Out:
# [1] "ts"

# %%
print(globtemp)
# Out:
# Time Series:
# Start = 1880
# End = 2015
# Frequency = 1
#   [1] -0.20 -0.11 -0.10 -0.20 -0.28 -0.31 -0.30 -0.33 -0.20 -0.11 -0.37 -0.24
#  [13] -0.27 -0.30 -0.31 -0.22 -0.15 -0.11 -0.28 -0.16 -0.09 -0.15 -0.28 -0.36
#  [25] -0.45 -0.28 -0.23 -0.40 -0.44 -0.47 -0.43 -0.44 -0.35 -0.35 -0.16 -0.11
#  [37] -0.33 -0.40 -0.26 -0.23 -0.26 -0.21 -0.27 -0.24 -0.28 -0.20 -0.09 -0.20
#  [49] -0.21 -0.36 -0.13 -0.09 -0.17 -0.28 -0.13 -0.19 -0.15 -0.02 -0.02 -0.03
#  [61]  0.08  0.13  0.10  0.14  0.26  0.12 -0.03 -0.04 -0.09 -0.09 -0.17 -0.06
#  [73]  0.01  0.08 -0.12 -0.14 -0.20  0.03  0.06  0.03 -0.03  0.05  0.02  0.06
#  [85] -0.20 -0.10 -0.05 -0.02 -0.07  0.07  0.03 -0.09  0.01  0.15 -0.08 -0.01
#  [97] -0.11  0.18  0.07  0.16  0.27  0.32  0.13  0.31  0.16  0.12  0.19  0.33
# [109]  0.40  0.28  0.44  0.42  0.23  0.24  0.32  0.46  0.34  0.48  0.63  0.42
# [121]  0.42  0.55  0.63  0.62  0.55  0.69  0.63  0.66  0.54  0.64  0.72  0.60
# [133]  0.63  0.66  0.75  0.87

# %%
options(repr.plot.width=9, repr.plot.height=5)
plot(globtemp, type = "o", 
     col="blue", 
     main="Global Mean Land-Ocean Temperature Deviations",
     xlab="Years", 
     ylab="Temprature Deviation")

#matplot(cbind(globtemp,globtempl),type="l",col=c("red","green"),lty=c(1,1))
# Out:
# Plot with title "Global Mean Land-Ocean Temperature Deviations"

# %%
sawtooth <- function(x, period){
    y <- (-2/pi) * atan(1/tan(x*period/pi))
    amp <- 19*log(x-min(x)+2)
    return( amp*y)
}

# %%
globtemp.linear.model <- lm(globtemp ~ time(globtemp))
globtemp.poly2.model <- lm(globtemp ~ poly(time(globtemp), 2, raw=TRUE))
globtemp.sawt.model <- lm(globtemp ~ poly(time(globtemp), 2, raw=TRUE)*sawtooth(time(globtemp), 1)*sin(2*pi*(time(globtemp)-2020)/63))
globtemp.sinos.model <- lm(globtemp ~ poly(time(globtemp), 2, raw=TRUE)*sin(2*pi*(time(globtemp)-2020)/63))

plot(globtemp, type = "o", 
     col="green", 
     main="Global Mean Land-Ocean Temperature Deviations",
     xlab="Years", 
     ylab="Deaths per 10000 People")

lines(x = as.vector(time(globtemp)), y = predict(globtemp.linear.model), col = 'red', lwd = 1.7)
lines(x = as.vector(time(globtemp)), y = predict(globtemp.poly2.model), col = 'blue', lwd = 1.7)
lines(x = as.vector(time(globtemp)), y = predict(globtemp.sawt.model), col = 'orange', lwd = 1.7)
lines(x = as.vector(time(globtemp)), y = predict(globtemp.sinos.model), col = 'brown', lwd = 1.7)

legend(x = "topleft", 
       legend=c("Original Time Series", "Linear Model", "Quadratic Model", "Sawtooth Model", "Quadratic Sinousoidal Model"), 
       col=c("green", "red", "blue", "orange", "brown"), 
       lwd=2, 
       text.font=0.2)
# Out:
# Plot with title "Global Mean Land-Ocean Temperature Deviations"

# %%
summary(globtemp.linear.model)
# Out:
# Call:
# lm(formula = globtemp ~ time(globtemp))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.33363 -0.11470 -0.02466  0.11932  0.38017
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)    -1.358e+01  6.747e-01  -20.13   <2e-16 ***
# time(globtemp)  6.984e-03  3.464e-04   20.16   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.1586 on 134 degrees of freedom
# Multiple R-squared:  0.7521,	Adjusted R-squared:  0.7503
# F-statistic: 406.6 on 1 and 134 DF,  p-value: < 2.2e-16

# %%
summary(globtemp.poly2.model)
# Out:
# Call:
# lm(formula = globtemp ~ poly(time(globtemp), 2, raw = TRUE))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.27014 -0.08379  0.00685  0.07299  0.38625
#
# Coefficients:
#                                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)                           2.844e+02  2.724e+01   10.44   <2e-16 ***
# poly(time(globtemp), 2, raw = TRUE)1 -2.992e-01  2.798e-02  -10.69   <2e-16 ***
# poly(time(globtemp), 2, raw = TRUE)2  7.860e-05  7.183e-06   10.94   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.1155 on 133 degrees of freedom
# Multiple R-squared:  0.8696,	Adjusted R-squared:  0.8676
# F-statistic: 443.3 on 2 and 133 DF,  p-value: < 2.2e-16

# %%
summary(globtemp.sawt.model)
# Out:
# Call:
# lm(formula = globtemp ~ poly(time(globtemp), 2, raw = TRUE) *
#     sawtooth(time(globtemp), 1) * sin(2 * pi * (time(globtemp) -
#     2020)/63))
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.209656 -0.069161  0.004644  0.067889  0.211249
#
# Coefficients:
#                                                                                                             Estimate
# (Intercept)                                                                                                3.108e+02
# poly(time(globtemp), 2, raw = TRUE)1                                                                      -3.263e-01
# poly(time(globtemp), 2, raw = TRUE)2                                                                       8.557e-05
# sawtooth(time(globtemp), 1)                                                                               -1.216e+00
# ...

# %%
summary(globtemp.sinos.model)
# Out:
# Call:
# lm(formula = globtemp ~ poly(time(globtemp), 2, raw = TRUE) *
#     sin(2 * pi * (time(globtemp) - 2020)/63))
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.195895 -0.077020  0.003646  0.073113  0.262018
#
# Coefficients:
#                                                                                 Estimate
# (Intercept)                                                                    3.097e+02
# poly(time(globtemp), 2, raw = TRUE)1                                          -3.251e-01
# poly(time(globtemp), 2, raw = TRUE)2                                           8.524e-05
# sin(2 * pi * (time(globtemp) - 2020)/63)                                       1.385e+02
# poly(time(globtemp), 2, raw = TRUE)1:sin(2 * pi * (time(globtemp) - 2020)/63) -1.424e-01
# poly(time(globtemp), 2, raw = TRUE)2:sin(2 * pi * (time(globtemp) - 2020)/63)  3.655e-05
#                                                                               Std. Error
# ...

# %%
plot(globtemp.linear.model)
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""

# %%
plot(globtemp.poly2.model)
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""

# %%
plot(globtemp.sawt.model)
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""

# %%
plot(globtemp.sinos.model)
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""

# %% [markdown]
# [Go To Index Section](#Time-Plots)

# %% [markdown]
# ## 4. Global Mean Land Temperature Deviations

# %%
help(globtempl)

# %%
class(globtempl)
# Out:
# [1] "ts"

# %%
print(globtempl)
# Out:
# Time Series:
# Start = 1880
# End = 2015
# Frequency = 1
#   [1] -0.53 -0.51 -0.41 -0.43 -0.72 -0.56 -0.70 -0.74 -0.53 -0.25 -0.61 -0.62
#  [13] -0.53 -0.56 -0.47 -0.39 -0.36 -0.27 -0.43 -0.35 -0.20 -0.19 -0.40 -0.46
#  [25] -0.56 -0.39 -0.27 -0.56 -0.42 -0.44 -0.37 -0.39 -0.37 -0.37 -0.11 -0.10
#  [37] -0.32 -0.54 -0.45 -0.21 -0.30 -0.19 -0.26 -0.28 -0.24 -0.27 -0.05 -0.19
#  [49] -0.11 -0.35 -0.15 -0.09 -0.11 -0.24 -0.09 -0.22 -0.09  0.01  0.07 -0.12
#  [61]  0.07  0.03  0.03 -0.03  0.04 -0.09 -0.09  0.04 -0.10 -0.13 -0.23 -0.08
#  [73] -0.04  0.04 -0.14 -0.13 -0.23  0.02  0.07  0.04 -0.03  0.09  0.02  0.02
#  [85] -0.25 -0.17 -0.06 -0.01 -0.09  0.02  0.08 -0.07 -0.02  0.23 -0.04  0.02
#  [97] -0.17  0.21  0.13  0.20  0.34  0.43  0.13  0.39  0.21  0.19  0.25  0.41
# [109]  0.51  0.38  0.52  0.52  0.23  0.27  0.38  0.56  0.48  0.54  0.83  0.59
# [121]  0.56  0.67  0.79  0.77  0.69  0.87  0.77  0.85  0.64  0.78  0.92  0.78
# [133]  0.77  0.82  0.88  0.98

# %%
options(repr.plot.width=9, repr.plot.height=5)
plot(globtempl, type = "o", 
     col="blue", 
     main="Global Mean Land Temperature Deviations",
     xlab="Years", 
     ylab="Temprature Deviation")
# Out:
# Plot with title "Global Mean Land Temperature Deviations"

# %%
globtempl.linear.model <- lm(globtempl ~ time(globtempl))
globtempl.poly2.model <- lm(globtempl ~ poly(time(globtempl), 2, raw=TRUE))
globtempl.sinos.model <- lm(globtempl ~ time(globtempl) * abs(sin(2*pi*(time(globtempl))/2)))

plot(globtempl, type = "o", 
     col="green", 
     main="Global Mean Land Temperature Deviations",
     xlab="Years", 
     ylab="Temprature Deviation")

lines(x = as.vector(time(globtempl)), y = predict(globtempl.linear.model), col = 'red', lwd = 1.7)
lines(x = as.vector(time(globtempl)), y = predict(globtempl.poly2.model), col = 'blue', lwd = 1.7)
lines(x = as.vector(time(globtempl)), y = predict(globtempl.sinos.model), col = 'brown', lwd = 1.7)

legend(x = "topleft", 
       legend=c("Original Time Series", "Linear Model", "Quadratic Model", "Linear Absolute Sinousoidal Model"), 
       col=c("green", "red", "blue", "brown"), 
       lwd=2, 
       text.font=0.2)
# Out:
# Plot with title "Global Mean Land Temperature Deviations"

# %% [markdown]
# [Go To Index Section](#Time-Plots)

# %% [markdown]
# ## 5. Variable Star

# %%
help(star)

# %%
class(star)
# Out:
# [1] "ts"

# %%
print(star)
# Out:
# Time Series:
# Start = 1
# End = 600
# Frequency = 1
#   [1] 25 28 31 32 33 33 32 31 28 25 22 18 14 10  7  4  2  0  0  0  2  4  8 11 15
#  [26] 19 23 26 29 32 33 34 33 32 30 27 24 20 17 13 10  7  5  3  3  3  4  5  7 10
#  [51] 13 16 19 22 24 26 27 28 29 28 27 25 24 21 19 17 15 13 12 11 11 10 10 11 12
#  [76] 12 13 14 15 16 17 18 19 19 19 19 20 20 20 20 20 20 20 20 21 20 20 20 20 19
# [101] 18 17 16 15 13 12 11 10  9  9 10 10 11 12 14 16 19 21 24 25 27 28 29 29 28
# [126] 27 25 23 20 17 14 11  8  5  4  2  2  2  4  6  9 12 16 19 23 27 30 32 33 34
# [151] 33 32 30 27 24 20 16 12  9  5  3  1  0  0  1  3  6  9 13 17 21 24 27 30 32
# [176] 33 33 32 31 28 25 22 19 15 12  9  7  5  4  4  5  5  7  9 12 14 17 20 22 24
# [201] 25 26 27 27 26 25 24 22 20 18 17 15 14 13 13 12 12 12 13 13 13 14 14 15 15
# [226] 16 17 17 17 17 18 18 19 19 20 20 21 21 22 22 22 22 22 21 20 19 17 16 14 12
# [251] 11  9  8  7  8  8  9 10 12 14 17 20 23 25 27 29 30 30 30 29 27 25 22 19 16
# ...

# %%
options(repr.plot.width=9, repr.plot.height=5)
plot(star, type = "o", 
     col="blue", 
     main="Variable Star",
     xlab="Day", 
     ylab="Magnitude")
# Out:
# Plot with title "Variable Star"

# %%
star.linear.model <- lm(star ~ time(star))
star.poly2.model <- lm(star ~ poly(time(star), 2, raw=TRUE))
star.sinos.model <- lm(star ~ time(star) * abs(sin(2*pi*(time(star))/2)))

plot(star, type = "o", 
     col="green", 
     main="Variable Star",
     xlab="Day", 
     ylab="Magnitude")

lines(x = as.vector(time(star)), y = predict(star.linear.model), col = 'red', lwd = 1.7)
lines(x = as.vector(time(star)), y = predict(star.poly2.model), col = 'blue', lwd = 1.7)
lines(x = as.vector(time(star)), y = predict(star.sinos.model), col = 'brown', lwd = 1.7)

legend(x = "topright", 
       legend=c("Original Time Series", "Linear Model", "Quadratic Model", "Linear Absolute Sinousoidal Model"), 
       col=c("green", "red", "blue", "brown"), 
       lwd=2, 
       text.font=0.2,
       cex = 0.55)
# Out:
# Plot with title "Variable Star"

# %% [markdown]
# [Go To Index Section](#Time-Plots)
